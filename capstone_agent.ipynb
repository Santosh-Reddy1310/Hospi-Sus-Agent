# %% [markdown]
# # Healthcare Sustainability AI Agent
# This notebook runs the multi-agent sustainability workflow: data collection, analysis, report generation, and intervention planning.

# %%
# Install required packages (uncomment to run in a fresh environment)
# !pip install crewai pandas matplotlib seaborn scikit-learn requests
print('Dependencies should already be installed in this environment.')

# %%
# Ensure project directories exist
import os
for d in ['agents','data','utils','outputs','logs','tests']:
    os.makedirs(d, exist_ok=True)
print('Directories ensured')

# %%
# Show project files to verify
import os
print('
'.join(sorted(os.listdir('.'))))

# %%
# Run the orchestrator and display structured results
from main_workflow import SustainabilityAgentOrchestrator
orchestrator = SustainabilityAgentOrchestrator()
results = orchestrator.run_full_workflow('data/hospital_energy.csv')
orchestrator.display_results(results)
